# %%
import requests
import json
import math
import xyzservices.providers as xyz
from pyproj import Transformer, transform

from bokeh.models import GeoJSONDataSource, CustomJS, Slider
from bokeh.plotting import figure, show, column
from bokeh.io import output_notebook

output_notebook()

def app(doc):
    TOOLTIPS = [('County', '@County')]
    transformer = Transformer.from_crs("EPSG:4326", "EPSG:3857", always_xy=True)
    
    data_url = 'https://incidents.fire.ca.gov/umbraco/api/IncidentApi/GeoJsonList?year='
    def fetchData(url):
        geojson_data = requests.get(url).json()
        return geojson_data
    
    data = fetchData(data_url + '2013')
    print(data_url + '2013')
    
    def process_json(geojson):
        for i in range(len(geojson['features'])):
            geojson['features'][i]['properties']['Color'] = 'blue'
        
        for i in range(len(geojson['features'])):
            coords = geojson['features'][i]['geometry']['coordinates']
            mercator_coords = transformer.transform(coords[0], coords[1])
            if math.isinf(mercator_coords[0]) or math.isinf(mercator_coords[1]):
                geojson['features'][i]['geometry']['coordinates'] = [0,0]
            else:
                geojson['features'][i]['geometry']['coordinates'] = list(transformer.transform(coords[0], coords[1]))
        return geojson
    
    geo_source = GeoJSONDataSource(geojson=json.dumps(process_json(data)))
    
    p = figure(x_range=(-14500000, -12500000), y_range=(4000000, 5000000),
               x_axis_type="mercator", y_axis_type="mercator", tooltips=TOOLTIPS)
    
    p.add_tile(xyz.OpenStreetMap.Mapnik, retina=True)
    p.scatter(x='x', y='y', size=15, color='Color', alpha=0.4, source=geo_source)
    
    date_slider = Slider(value=2013,
                         start=2013,
                         end=2025
                        )
    
    def callback(attr, old, new):
        new_data = fetchData(data_url + str(new))
        geo_source.geojson = json.dumps(process_json(new_data))
    
    
    date_slider.on_change("value", callback)
    
    layout = column(date_slider, p)
    
    doc.add_root(layout)

show(app)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="edf5db16-93e0-486c-ae77-68fd5652ed60">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 62
#      58     layout = column(date_slider, p)
#      60     curdoc().add_root(layout)
# ---> 62 show(app)
#
# File /opt/anaconda3/lib/python3.12/site-packages/bokeh/io/showing.py:156, in show(obj, browser, new, notebook_handle, notebook_url, **kwargs)
#     152 if is_application(obj) or callable(obj): # TODO (bev) check callable signature more thoroughly
#     153     # This ugliness is to prevent importing bokeh.application (which would bring
#     154     # in Tornado) just in order to show a non-server object
#     155     assert state.notebook_type is not None
# --> 156     return run_notebook_hook(state.notebook_type, 'app', obj, state, notebook_url, **kwargs)
#     158 raise ValueError(_BAD_SHOW_MSG)
#
# File /opt/anaconda3/lib/python3.12/site-packages/bokeh/io/notebook.py:371, in run_notebook_hook(notebook_type, action, *args, **kwargs)
#     369 if _HOOKS[notebook_type][action] is None:
#     370     raise RuntimeError(f"notebook hook for {notebook_type!r} did not install {action!r} action")
# --> 371 return _HOOKS[notebook_type][action](*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/bokeh/io/notebook.py:568, in show_app(app, state, notebook_url, port, **kw)
#     565 else:
#     566     origin = _origin_url(notebook_url)
# --> 568 server = Server({"/": app}, io_loop=loop, port=port, allow_websocket_origin=[origin], **kw)
#     570 server_id = ID(uuid4().hex)
#     571 curstate().uuid_to_server[server_id] = server
#
# File /opt/anaconda3/lib/python3.12/site-packages/bokeh/server/server.py:438, in Server.__init__(self, applications, io_loop, http_server_kwargs, **kwargs)
#     435 self._absolute_url = server_url(self._address, self._port, opts.ssl_certfile is not None)
#     437 try:
# --> 438     tornado_app = BokehTornado(applications,
#     439                                extra_websocket_origins=extra_websocket_origins,
#     440                                absolute_url=self._absolute_url,
#     441                                prefix=opts.prefix,
#     442                                index=opts.index,
#     443                                websocket_max_message_size_bytes=opts.websocket_max_message_size,
#     444                                **kwargs)
#     446     if opts.num_procs != 1:
#     447         assert all(app_context.application.safe_to_fork for app_context in tornado_app.applications.values()), (
#     448               'User application code has run before attempting to start '
#     449               'multiple processes. This is considered an unsafe operation.')
#
# File /opt/anaconda3/lib/python3.12/site-packages/bokeh/server/tornado.py:297, in BokehTornado.__init__(self, applications, absolute_url, prefix, extra_websocket_origins, extra_patterns, secret_key, sign_sessions, generate_session_ids, keep_alive_milliseconds, check_unused_sessions_milliseconds, unused_session_lifetime_milliseconds, stats_log_frequency_milliseconds, mem_log_frequency_milliseconds, use_index, redirect_root, websocket_max_message_size_bytes, websocket_compression_level, websocket_compression_mem_level, ico_path, index, auth_provider, xsrf_cookies, include_headers, include_cookies, exclude_headers, exclude_cookies, session_token_expiration, **kwargs)
#     295 for url, app in list(applications.items()):
#     296     if callable(app):
# --> 297         applications[url] = app = Application(FunctionHandler(app))
#     298     if all(not isinstance(handler, DocumentLifecycleHandler) for handler in app._handlers):
#     299         app.add(DocumentLifecycleHandler())
#
# File /opt/anaconda3/lib/python3.12/site-packages/bokeh/application/handlers/function.py:113, in FunctionHandler.__init__(self, func, trap_exceptions)
#      92 '''
#      93
#      94 Args:
#    (...)
#     109
#     110 '''
#     111 super().__init__()
# --> 113 _check_callback(func, ('doc',))
#     115 self._func = func
#     116 self._trap_exceptions = trap_exceptions
#
# File /opt/anaconda3/lib/python3.12/site-packages/bokeh/util/callback_manager.py:203, in _check_callback(callback, fargs, what)
#     201 expected = ", ".join(fargs)
#     202 received = str(sig)
# --> 203 raise ValueError(f"{what} must have signature func({expected}), got func{received}")
#
# ValueError: Callback functions must have signature func(doc), got func()
